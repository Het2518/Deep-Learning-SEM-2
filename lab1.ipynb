# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import classification_report, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
file_path = "fake_reviews_dataset - fake_reviews_dataset.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0            category     rating      label
# 1  Home_and_Kitchen_5          5         CG
# 2  Home_and_Kitchen_5          5         CG
# 3  Home_and_Kitchen_5          5         CG
# 4  Home_and_Kitchen_5          1         CG
#
#                                           Unnamed: 3
# 0                                              text_
# 1  Love this!  Well made, sturdy, and very comfor...
# 2  love it, a great upgrade from the original.  I...
# 3  This pillow saved my back. I love the look and...
# 4  Missing information on how to use it, but it i...

# %%
df.columns = ["category", "rating", "authenticity", "review"]

df = df[df["category"] != "category"]
df = df.dropna()

df.head()
# Out:
#              category rating authenticity  \
# 1  Home_and_Kitchen_5      5           CG
# 2  Home_and_Kitchen_5      5           CG
# 3  Home_and_Kitchen_5      5           CG
# 4  Home_and_Kitchen_5      1           CG
# 5  Home_and_Kitchen_5      5           CG
#
#                                               review
# 1  Love this!  Well made, sturdy, and very comfor...
# 2  love it, a great upgrade from the original.  I...
# 3  This pillow saved my back. I love the look and...
# 4  Missing information on how to use it, but it i...
# 5  Very nice set. Good quality. We have had the s...

# %%
df.info()
df["category"].value_counts()
df["authenticity"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40432 entries, 1 to 40432
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   category      40432 non-null  object
#  1   rating        40432 non-null  object
#  2   authenticity  40432 non-null  object
#  3   review        40432 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB
# authenticity
# CG    20216
# OR    20216
# Name: count, dtype: int64

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X = tfidf.fit_transform(df["review"]).toarray()

y_category = df["category"]

# %%
le = LabelEncoder()
y_cat_encoded = le.fit_transform(y_category)

y_cat_onehot = to_categorical(y_cat_encoded)

# %%
X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
    X, y_cat_onehot, test_size=0.2, random_state=42
)

# %%
cat_model = Sequential()

cat_model.add(Dense(512, activation='relu', input_shape=(5000,)))
cat_model.add(Dropout(0.3))

cat_model.add(Dense(256, activation='relu'))
cat_model.add(Dropout(0.3))

cat_model.add(Dense(y_cat_onehot.shape[1], activation='softmax'))

cat_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

cat_model.summary()
# Out:
# c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │     2,560,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,694,410 (10.28 MB)
#  Trainable params: 2,694,410 (10.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_cat = cat_model.fit(
    X_train_c, y_train_c,
    epochs=5,
    batch_size=256,
    validation_split=0.1
)
# Out:
# Epoch 1/5
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.6201 - loss: 1.2133 - val_accuracy: 0.7703 - val_loss: 0.6505
# Epoch 2/5
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8193 - loss: 0.5196 - val_accuracy: 0.7737 - val_loss: 0.6384
# Epoch 3/5
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8624 - loss: 0.3921 - val_accuracy: 0.7641 - val_loss: 0.6706
# Epoch 4/5
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8928 - loss: 0.3120 - val_accuracy: 0.7555 - val_loss: 0.7220
# Epoch 5/5
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9160 - loss: 0.2485 - val_accuracy: 0.7493 - val_loss: 0.7981

# %%
y_pred_prob = cat_model.predict(X_test_c)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_test_c, axis=1)

# If you want to see the predicted category names:
y_pred_labels = le.inverse_transform(y_pred)
y_true_labels = le.inverse_transform(y_true)

print("Accuracy:", accuracy_score(y_true, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=le.classes_))
# Out:
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Accuracy: 0.7617163348584147
#
# Classification Report:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 11
#       9 print("Accuracy:", accuracy_score(y_true, y_pred))
#      10 print("\nClassification Report:\n")
# ---> 11 print(classification_report(y_true, y_pred, target_names=le.classes_))
#
# File c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:3107, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    3105 headers = ["precision", "recall", "f1-score", "support"]
#    3106 # compute per-class results without averaging
# -> 3107 p, r, f1, s = precision_recall_fscore_support(
#    3108     y_true,
#    3109     y_pred,
#    3110     labels=labels,
#    3111     average=None,
#    3112     sample_weight=sample_weight,
#    3113     zero_division=zero_division,
#    3114 )
#    3115 rows = zip(target_names, p, r, f1, s)
#    3117 if y_type.startswith("multilabel"):
#
# File c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:2104, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    2102 # Calculate tp_sum, pred_sum, true_sum ###
#    2103 samplewise = average == "samples"
# -> 2104 MCM = multilabel_confusion_matrix(
#    2105     y_true,
#    2106     y_pred,
#    2107     sample_weight=sample_weight,
#    2108     labels=labels,
#    2109     samplewise=samplewise,
#    2110 )
#    2111 tp_sum = MCM[:, 1, 1]
#    2112 pred_sum = tp_sum + MCM[:, 0, 1]
#
# File c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\VASU MONPARA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:774, in multilabel_confusion_matrix(y_true, y_pred, sample_weight, labels, samplewise)
#     772 le = LabelEncoder()
#     773 le.fit(labels)
# --> 774 y_true = le.transform(y_true)
#     775 y_pred = le.transform(y_pred)
#     776 sorted_labels = le.classes_
#
# AttributeError: 'LabelEncoder' object has no attribute 'transform'
